# %%
from bittrex.bittrex import Bittrex, API_V2_0

my_bittrex = Bittrex(None, None)  # or defaulting to v1.1 as Bittrex(None, None)
my_bittrex.get_markets()
dfd = pd.DataFrame(my_bittrex.get_market_history("BTC-DOGE")[ 'result'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-060313c7c378> in <module>()
#       3 my_bittrex = Bittrex(None, None)  # or defaulting to v1.1 as Bittrex(None, None)
#       4 my_bittrex.get_markets()
# ----> 5 dfd = pd.DataFrame(my_bittrex.get_market_history("BTC-DOGE")[ 'result'])
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
dfd = pd.DataFrame(my_bittrex.get_market_history("BTC-DOGE")[ 'result'])

# %%
dfma = pd.DataFrame(my_bittrex.get_markets()['result']['MarketName'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-dfc81db12695> in <module>()
# ----> 1 dfma = pd.DataFrame(my_bittrex.get_markets()['result']['MarketName'])
#
# TypeError: list indices must be integers, not str

# %%
dfma = pd.DataFrame(my_bittrex.get_markets()['result'])

# %%
dfma['MarketName']
# Out:
# 0        BTC-LTC
# 1       BTC-DOGE
# 2        BTC-VTC
# 3        BTC-PPC
# 4        BTC-FTC
# 5        BTC-RDD
# 6        BTC-NXT
# 7       BTC-DASH
# 8        BTC-POT
# 9        BTC-BLK
# 10      BTC-EMC2
# 11       BTC-XMY
# 12       BTC-AUR
# 13       BTC-EFL
# 14       BTC-GLD
# 15       BTC-SLR
# 16       BTC-PTC
# 17       BTC-GRS
# 18       BTC-NLG
# 19       BTC-RBY
# 20       BTC-XWC
# 21      BTC-MONA
# 22       BTC-THC
# 23      BTC-ENRG
# 24       BTC-ERC
# 25       BTC-VRC
# 26      BTC-CURE
# 27       BTC-XMR
# 28     BTC-CLOAK
# 29     BTC-START
#          ...
# 236    ETH-WAVES
# 237    ETH-STRAT
# 238      ETH-DGB
# 239      ETH-FCT
# 240     USDT-OMG
# 241      BTC-ADA
# 242     BTC-MANA
# 243     ETH-MANA
# 244     BTC-SALT
# 245     ETH-SALT
# 246      BTC-TIX
# 247      ETH-TIX
# 248      BTC-RCN
# 249      ETH-RCN
# 250      BTC-VIB
# 251      ETH-VIB
# 252      BTC-MER
# 253     BTC-POWR
# 254     ETH-POWR
# 255      BTC-BTG
# 256      ETH-BTG
# ...

# %%
dfma['MarketName'][1].find('BTC-')!=-1
# Out:
# True

# %%
dfma['MarketName'][260].find('BTC-')!=-1
# Out:
# False

# %%
dfda[1] = pd.DataFrame(my_bittrex.get_market_history(dfma['MarketName'][1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e686c5bc0945> in <module>()
# ----> 1 dfda[1] = pd.DataFrame(my_bittrex.get_market_history(dfma['MarketName'][1]))
#
# NameError: name 'dfda' is not defined

# %%
dfda = pd.DataFrame(my_bittrex.get_market_history(dfma['MarketName'][2]))

# %%
dfda
# Out:
#    message                                             result  success
# 0           {'FillType': 'FILL', 'Quantity': 39.14756184, ...     True
# 1           {'FillType': 'FILL', 'Quantity': 4.0689325, 'T...     True
# 2           {'FillType': 'FILL', 'Quantity': 82.26663473, ...     True
# 3           {'FillType': 'PARTIAL_FILL', 'Quantity': 15.30...     True
# 4           {'FillType': 'FILL', 'Quantity': 2.52194088, '...     True
# 5           {'FillType': 'FILL', 'Quantity': 7.56582265, '...     True
# 6           {'FillType': 'FILL', 'Quantity': 8.776512, 'Ti...     True
# 7           {'FillType': 'FILL', 'Quantity': 2.87889139, '...     True
# 8           {'FillType': 'PARTIAL_FILL', 'Quantity': 199.4...     True
# 9           {'FillType': 'FILL', 'Quantity': 20.59185062, ...     True
# 10          {'FillType': 'FILL', 'Quantity': 3.27657094, '...     True
# 11          {'FillType': 'PARTIAL_FILL', 'Quantity': 30.0,...     True
# ...

# %%
dfda = pd.DataFrame(my_bittrex.get_market_history(dfma['MarketName'][2])[ 'result'])

# %%
dfda
# Out:
#         FillType        Id OrderType     Price    Quantity  \
# 0   PARTIAL_FILL  46276634      SELL  0.000393    6.410393
# 1           FILL  46276633      SELL  0.000393    7.615667
# 2           FILL  46276632      SELL  0.000393   25.381679
# 3           FILL  46276631      SELL  0.000393   27.678518
# 4           FILL  46276630      SELL  0.000393    8.000000
# 5           FILL  46276629      SELL  0.000393   25.000000
# 6           FILL  46276628      SELL  0.000393   26.954863
# 7           FILL  46276627      SELL  0.000393  331.788092
# 8           FILL  46276626      SELL  0.000394  300.000000
# 9           FILL  46276625      SELL  0.000394    2.569895
# 10          FILL  46276624      SELL  0.000394   25.317259
# 11          FILL  46276623      SELL  0.000394   28.036155
# 12          FILL  46276622      SELL  0.000394    6.328096
# 13          FILL  46276621      SELL  0.000394    1.298528
# 14          FILL  46276620      SELL  0.000394  200.000000
# ...

# %%
dfda['TimeStamp']
# Out:
# 0     2018-01-26T08:55:18.297
# 1     2018-01-26T08:55:18.297
# 2     2018-01-26T08:55:18.297
# 3     2018-01-26T08:55:18.297
# 4     2018-01-26T08:55:18.297
# 5     2018-01-26T08:55:18.297
# 6     2018-01-26T08:55:18.297
# 7     2018-01-26T08:55:18.297
# 8     2018-01-26T08:55:18.297
# 9     2018-01-26T08:55:18.297
# 10    2018-01-26T08:55:18.297
# 11    2018-01-26T08:55:18.297
# 12    2018-01-26T08:55:18.297
# 13    2018-01-26T08:55:18.297
# 14    2018-01-26T08:55:18.297
# 15    2018-01-26T08:55:18.297
# 16    2018-01-26T08:55:18.297
# 17    2018-01-26T08:55:18.297
# 18    2018-01-26T08:55:18.297
# 19    2018-01-26T08:55:18.297
# 20    2018-01-26T08:55:18.297
# 21    2018-01-26T08:55:18.297
# 22    2018-01-26T08:55:18.297
# 23    2018-01-26T08:55:18.297
# 24    2018-01-26T08:55:18.297
# 25     2018-01-26T08:55:18.28
# 26     2018-01-26T08:55:18.28
# 27     2018-01-26T08:55:18.28
# 28     2018-01-26T08:55:18.28
# 29     2018-01-26T08:55:18.28
#                ...
# ...

# %%
datetime.now().isoformat()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e44dc9b04b13> in <module>()
# ----> 1 datetime.now().isoformat()
#
# NameError: name 'datetime' is not defined

# %%
from datetime import datetime

# %%
datetime.now().isoformat()
# Out:
# '2018-01-26T19:58:41.941547'

# %%
dfda['TimeStamp'][2]
# Out:
# '2018-01-26T08:55:18.297'

# %%
dfma['MarketName'][x].find(datetime.now().strftime("%H:%M:"))!=-1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5ce8bb4913b4> in <module>()
# ----> 1 dfma['MarketName'][x].find(datetime.now().strftime("%H:%M:"))!=-1
#
# NameError: name 'x' is not defined

# %%
dfma['MarketName'][1].find(datetime.now().strftime("%H:%M:"))!=-1
# Out:
# False

# %%
datetime.now().strftime("%H:%M:")
# Out:
# '20:03:'

# %%
datetime.now(-1).strftime("%H:%M:")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-c448856b8b77> in <module>()
# ----> 1 datetime.now(-1).strftime("%H:%M:")
#
# TypeError: tzinfo argument must be None or of a tzinfo subclass, not type 'int'

# %%
datetime.timedelta(minutes=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-b6fe1bb867aa> in <module>()
# ----> 1 datetime.timedelta(minutes=1)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'timedelta'

# %%
from datetime import datetime,timedelta

# %%
datetime.datetime.now() - datetime.timedelta(0, 900)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-1f1f090d8e11> in <module>()
# ----> 1 datetime.datetime.now() - datetime.timedelta(0, 900)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
datetime.timedelta(minutes=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-b6fe1bb867aa> in <module>()
# ----> 1 datetime.timedelta(minutes=1)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'timedelta'

# %%
 from datetime import timedelta

# %%
datetime.timedelta(minutes=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-b6fe1bb867aa> in <module>()
# ----> 1 datetime.timedelta(minutes=1)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'timedelta'

# %%
d = timedelta(milliseconds=-1)

# %%
d
# Out:
# datetime.timedelta(-1, 86399, 999999)

# %%
datetime.now()-d
# Out:
# datetime.datetime(2018, 1, 26, 20, 18, 50, 400356)

# %%
d = timedelta(milliseconds=-1)

# %%
d = timedelta(seconds=-30)

# %%
datetime.now()-d
# Out:
# datetime.datetime(2018, 1, 26, 20, 21, 25, 638474)

# %%
datetime.now()-d
# Out:
# datetime.datetime(2018, 1, 26, 20, 21, 46, 468920)

# %%
dfd = pd.DataFrame(my_bittrex.get_market_history("BTC-DOGE")[ 'result'])

# %%
dfd
# Out:
#         FillType        Id OrderType         Price      Quantity  \
# 0   PARTIAL_FILL  12842021      SELL  6.400000e-07  1.911726e+04
# 1   PARTIAL_FILL  12842020      SELL  6.400000e-07  7.832031e+05
# 2   PARTIAL_FILL  12842019      SELL  6.400000e-07  1.453453e+05
# 3   PARTIAL_FILL  12842016      SELL  6.400000e-07  4.048971e+03
# 4           FILL  12842000       BUY  6.500000e-07  8.770488e+03
# 5           FILL  12841998       BUY  6.500000e-07  1.000000e+03
# 6   PARTIAL_FILL  12841981      SELL  6.400000e-07  8.423949e+03
# 7   PARTIAL_FILL  12841973      SELL  6.400000e-07  1.874566e+03
# 8           FILL  12841972       BUY  6.500000e-07  1.003001e+03
# 9           FILL  12841970       BUY  6.500000e-07  8.770488e+03
# 10  PARTIAL_FILL  12841968      SELL  6.400000e-07  2.628013e+05
# 11  PARTIAL_FILL  12841963      SELL  6.400000e-07  2.377000e+03
# 12          FILL  12841956       BUY  6.500000e-07  8.781895e+03
# ...
